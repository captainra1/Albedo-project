# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
# plotting the maps of all dataset.
# note: color of maps may differ due to different color schemes value i.e,(cmap value.)

# %%
albedo_map_data=pd.read_csv("..\ML4SCI_GSoC\Messenger\Moon\Albedo_Map.csv",header=None)

# %%
albedo_map_data.head(5)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.331936  0.332611  0.332240  0.331028  0.331094  0.332614  0.331964
# 1  0.338990  0.340417  0.334623  0.333716  0.331404  0.331733  0.335648
# 2  0.324930  0.325832  0.328177  0.325871  0.321231  0.321791  0.322595
# 3  0.327572  0.327171  0.333880  0.326805  0.328176  0.327048  0.326413
# 4  0.347444  0.340715  0.330832  0.335570  0.340129  0.332496  0.335220
#
#         7         8         9    ...       710       711       712       713  \
# 0  0.329994  0.327853  0.326532  ...  0.330389  0.329089  0.330334  0.333719
# 1  0.335849  0.333166  0.332413  ...  0.350386  0.346509  0.341890  0.345887
# 2  0.325254  0.329132  0.325335  ...  0.329577  0.332204  0.330471  0.330105
# 3  0.332305  0.325137  0.325540  ...  0.317473  0.314289  0.321126  0.317036
# 4  0.336632  0.334052  0.328328  ...  0.319792  0.332530  0.334123  0.332214
#
#         714       715       716       717       718       719
# 0  0.334709  0.334640  0.332491  0.334664  0.332983  0.331635
# 1  0.345619  0.344203  0.345772  0.341238  0.342606  0.338984
# 2  0.331836  0.335386  0.335075  0.333190  0.327436  0.330122
# 3  0.320553  0.312072  0.311713  0.315656  0.317066  0.319407
# 4  0.343655  0.333832  0.352028  0.340800  0.348094  0.349389
#
# [5 rows x 720 columns]

# %%
albedo_map_data.describe()
# Out:
#               0           1           2           3           4           5    \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     0.302457    0.300313    0.305411    0.302052    0.305815    0.302412
# std      0.046314    0.050141    0.046161    0.052069    0.046651    0.048005
# min      0.141172    0.163120    0.169143    0.155732    0.157913    0.179285
# 25%      0.270387    0.261086    0.274612    0.270031    0.274149    0.265750
# 50%      0.314536    0.316147    0.319692    0.318961    0.319510    0.315784
# 75%      0.336231    0.337058    0.338903    0.337865    0.336247    0.333630
# max      0.408014    0.394116    0.394901    0.443510    0.466874    0.435901
#
#               6           7           8           9    ...         710  \
# count  360.000000  360.000000  360.000000  360.000000  ...  360.000000
# mean     0.305667    0.301788    0.304058    0.301751  ...    0.304580
# std      0.042653    0.046145    0.043310    0.049643  ...    0.046566
# min      0.212120    0.182382    0.202475    0.186705  ...    0.179880
# 25%      0.271608    0.265047    0.267298    0.260819  ...    0.271671
# 50%      0.317110    0.316191    0.315347    0.318071  ...    0.314546
# 75%      0.336033    0.333705    0.336063    0.337597  ...    0.333788
# max      0.415883    0.389032    0.391424    0.402550  ...    0.412596
#
#               711         712         713         714         715         716  \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     0.303428    0.305631    0.303635    0.304501    0.300814    0.300133
# std      0.050896    0.049252    0.051832    0.049628    0.052960    0.052445
# min      0.164281    0.155969    0.166897    0.167841    0.160124    0.147287
# 25%      0.267380    0.272131    0.264016    0.267056    0.266689    0.267223
# 50%      0.316398    0.317085    0.317109    0.314048    0.312624    0.309758
# 75%      0.335329    0.334627    0.336448    0.336000    0.337990    0.336942
# max      0.433865    0.467690    0.477983    0.480166    0.448398    0.423606
#
#               717         718         719
# count  360.000000  360.000000  360.000000
# mean     0.301454    0.303223    0.299800
# std      0.050324    0.045171    0.049668
# min      0.156590    0.137881    0.140771
# 25%      0.265485    0.267691    0.260281
# 50%      0.316195    0.315086    0.313502
# 75%      0.340425    0.337306    0.334680
# max      0.394808    0.395146    0.397876
#
# [8 rows x 720 columns]

# %% [markdown]
# ## Visualizing all dataset.

# %%
plt.figure(figsize=(15,7))
plt.imshow(albedo_map_data,cmap='gist_gray')
#sns.heatmap(albedo_map_data,xticklabels=False,yticklabels=False,cmap='gray')

# %%
Fe_map_data=pd.read_csv('..\ML4SCI_GSoC\Messenger\Moon\LPFe_Map.csv',header=None)

# %%
Fe_map_data.describe()
# Out:
#               0           1           2           3           4           5    \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     4.567701    4.567701    4.567701    4.566329    4.479381    4.375827
# std      1.876054    1.876054    1.876054    1.877146    1.953113    1.847930
# min      1.928140    1.928140    1.928140    1.928140    1.696970    1.696970
# 25%      3.197270    3.197270    3.197270    3.197270    3.155380    3.015230
# 50%      3.783955    3.783955    3.783955    3.783955    3.759510    3.835610
# 75%      5.855480    5.855480    5.855480    5.855480    5.962750    5.953260
# max     10.067900   10.067900   10.067900   10.067900   10.067900    8.800820
#
#               6           7           8           9    ...         710  \
# count  360.000000  360.000000  360.000000  360.000000  ...  360.000000
# mean     4.428743    4.428743    4.549505    4.554067  ...    4.354266
# std      1.945467    1.945467    1.908253    1.897785  ...    1.711379
# min      1.696970    1.696970    1.289190    1.289190  ...    1.416900
# 25%      3.084720    3.084720    3.166730    3.231710  ...    2.963850
# 50%      3.759510    3.759510    3.835610    3.751275  ...    3.785745
# 75%      5.963600    5.963600    5.963600    5.963600  ...    5.909500
# max      9.020030    9.020030    9.020030    9.020030  ...    8.316550
#
#               711         712         713         714         715         716  \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     4.356564    4.274216    4.274216    4.246132    4.223777    4.304209
# std      1.686375    1.816606    1.816606    1.798304    1.703797    1.739148
# min      1.416900    1.584960    1.584960    1.584960    1.584960    0.768544
# 25%      3.066680    2.983040    2.983040    2.949460    2.994160    2.994160
# 50%      3.820805    3.799425    3.799425    3.799425    3.817070    3.852560
# 75%      5.898000    5.887270    5.887270    5.673040    5.513770    5.673040
# max      8.316550    9.072880    9.072880    9.072880    9.072880    8.746410
#
#               717         718         719
# count  360.000000  360.000000  360.000000
# mean     4.290884    4.290884    4.290884
# std      1.752005    1.752005    1.752005
# min      0.768544    0.768544    0.768544
# 25%      2.967420    2.967420    2.967420
# 50%      3.852560    3.852560    3.852560
# 75%      5.673040    5.673040    5.673040
# max      8.746410    8.746410    8.746410
#
# [8 rows x 720 columns]

# %%
plt.figure(figsize=(15,7))
plt.imshow(Fe_map_data,cmap='jet')
#sns.heatmap(Fe_map_data,xticklabels=False,yticklabels=False,cmap='jet')

# %%
K_map_data=pd.read_csv('..\ML4SCI_GSoC\Messenger\Moon\LPK_Map.csv',header=None)

# %%
K_map_data.describe()
# Out:
#                0            1            2            3            4    \
# count   360.000000   360.000000   360.000000   360.000000   360.000000
# mean    572.223048   572.223048   572.223048   567.202714   537.029686
# std     408.997593   408.997593   408.997593   409.872902   376.675661
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     242.850000   242.850000   242.850000   242.850000   254.600000
# 50%     539.460000   539.460000   539.460000   530.950000   462.600000
# 75%     866.220000   866.220000   866.220000   866.220000   858.780000
# max    1628.300000  1628.300000  1628.300000  1628.300000  1479.700000
#
#                5            6            7            8            9    ...  \
# count   360.000000   360.000000   360.000000   360.000000   360.000000  ...
# mean    537.808463   514.527341   514.527341   549.976017   557.100972  ...
# std     365.355167   358.142129   358.142129   342.809290   348.274028  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     254.600000   236.670000   236.670000   276.740000   277.190000  ...
# 50%     462.600000   446.570000   446.570000   510.740000   510.740000  ...
# 75%     872.920000   724.752500   724.752500   858.780000   883.240000  ...
# max    1389.400000  1389.400000  1389.400000  1356.500000  1356.500000  ...
#
#                710          711          712          713          714  \
# count   360.000000   360.000000   360.000000   360.000000   360.000000
# mean    564.500200   551.644978   537.770428   537.770428   532.287550
# std     384.462047   391.440931   401.031593   401.031593   393.437613
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     251.450000   242.090000   251.450000   251.450000   251.050000
# 50%     492.850000   482.200000   449.515000   449.515000   429.385000
# 75%     897.880000   897.880000   833.730000   833.730000   824.530000
# max    1552.700000  1552.700000  1509.900000  1509.900000  1509.900000
#
#                715          716          717          718          719
# count   360.000000   360.000000   360.000000   360.000000   360.000000
# mean    532.101883   542.456900   542.787011   542.787011   542.787011
# std     392.492356   383.779084   383.599046   383.599046   383.599046
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     282.220000   243.310000   243.310000   243.310000   243.310000
# 50%     414.020000   454.655000   454.655000   454.655000   454.655000
# 75%     824.530000   839.840000   839.840000   839.840000   839.840000
# max    1509.900000  1358.600000  1358.600000  1358.600000  1358.600000
#
# [8 rows x 720 columns]

# %%
plt.subplots(figsize=(15,7))
sns.heatmap(K_map_data,xticklabels=False,yticklabels=False,cmap='jet')

# %%
Th_map_data=pd.read_csv('..\ML4SCI_GSoC\Messenger\Moon\LPTh_Map.csv',header=None)

# %%
Th_map_data.describe()
# Out:
#               0           1           2           3           4           5    \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     1.165303    1.165303    1.165303    1.175875    1.130200    1.119703
# std      0.812062    0.812062    0.812062    0.807948    0.788789    0.786537
# min      0.223560    0.223560    0.223560    0.223560    0.003663    0.003663
# 25%      0.522790    0.522790    0.522790    0.537450    0.493600    0.470010
# 50%      0.839370    0.839370    0.839370    0.860850    0.798020    0.791475
# 75%      1.832400    1.832400    1.832400    1.832400    1.832400    1.832400
# max      3.019000    3.019000    3.019000    3.019000    2.705900    2.705900
#
#               6           7           8           9    ...         710  \
# count  360.000000  360.000000  360.000000  360.000000  ...  360.000000
# mean     1.123195    1.123195    1.168785    1.168844  ...    1.254754
# std      0.790808    0.790808    0.828879    0.828787  ...    0.842611
# min      0.003663    0.003663    0.003663    0.003663  ...    0.003663
# 25%      0.470010    0.470010    0.498040    0.498040  ...    0.670010
# 50%      0.774450    0.774450    0.798020    0.814140  ...    0.904780
# 75%      1.877000    1.877000    1.977000    1.977000  ...    1.958300
# max      2.705900    2.705900    2.871900    2.871900  ...    3.610900
#
#               711         712         713         714         715         716  \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     1.255866    1.205392    1.205392    1.202336    1.191273    1.171854
# std      0.843969    0.798826    0.798826    0.787780    0.807104    0.789894
# min      0.003663    0.139570    0.139570    0.139570    0.139570    0.139570
# 25%      0.678790    0.594080    0.594080    0.594080    0.586230    0.558710
# 50%      0.904780    0.861870    0.861870    0.859920    0.859920    0.841540
# 75%      1.958300    1.919400    1.919400    1.897400    1.890700    1.890700
# max      3.610900    3.545500    3.545500    3.545500    3.545500    2.987900
#
#               717         718         719
# count  360.000000  360.000000  360.000000
# mean     1.177726    1.177726    1.177726
# std      0.785587    0.785587    0.785587
# min      0.139570    0.139570    0.139570
# 25%      0.562750    0.562750    0.562750
# 50%      0.862890    0.862890    0.862890
# 75%      1.890700    1.890700    1.890700
# max      2.987900    2.987900    2.987900
#
# [8 rows x 720 columns]

# %%
plt.subplots(figsize=(15,7))
sns.heatmap(Th_map_data,xticklabels=False,yticklabels=False,cmap='jet')

# %%
Ti_map_data=pd.read_csv('..\ML4SCI_GSoC\Messenger\Moon\LPTi_Map.csv',header=None)

# %%
Ti_map_data.describe()
# Out:
#               0           1           2           3           4           5    \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     0.282861    0.282861    0.282861    0.281055    0.283921    0.251162
# std      0.263021    0.263021    0.263021    0.264388    0.288946    0.265053
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.053144    0.053144    0.053144    0.039717    0.001493    0.000000
# 50%      0.224463    0.224463    0.224463    0.224463    0.224463    0.188547
# 75%      0.433349    0.433349    0.433349    0.433349    0.430634    0.414709
# max      1.346300    1.346300    1.346300    1.346300    1.346300    1.167940
#
#               6           7           8           9    ...         710  \
# count  360.000000  360.000000  360.000000  360.000000  ...  360.000000
# mean     0.247943    0.247943    0.273375    0.278751  ...    0.264408
# std      0.251941    0.251941    0.266742    0.270227  ...    0.263159
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    0.000000    0.053144    0.057663  ...    0.045096
# 50%      0.204046    0.204046    0.219494    0.219494  ...    0.209794
# 75%      0.372863    0.372863    0.423352    0.431413  ...    0.399150
# max      1.167940    1.167940    1.356670    1.356670  ...    1.169800
#
#               711         712         713         714         715         716  \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     0.264113    0.221611    0.221611    0.243636    0.222072    0.236005
# std      0.265915    0.258312    0.258312    0.276481    0.259813    0.226962
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.041281    0.000000    0.000000    0.000000    0.000000    0.003323
# 50%      0.209794    0.190684    0.190684    0.205095    0.190684    0.205095
# 75%      0.402848    0.294967    0.294967    0.326552    0.305893    0.395998
# max      1.169800    1.703870    1.703870    1.703870    1.703870    1.033510
#
#               717         718         719
# count  360.000000  360.000000  360.000000
# mean     0.229395    0.229395    0.229395
# std      0.211751    0.211751    0.211751
# min      0.000000    0.000000    0.000000
# 25%      0.003323    0.003323    0.003323
# 50%      0.205095    0.205095    0.205095
# 75%      0.395998    0.395998    0.395998
# max      0.761885    0.761885    0.761885
#
# [8 rows x 720 columns]

# %%
plt.subplots(figsize=(15,7))
plt.imshow(Ti_map_data,cmap='jet')
#sns.heatmap(Ti_map_data,xticklabels=False,yticklabels=False,cmap='jet')

# %% [markdown]
# ## data preprocessing

# %%
# now splitting the label dataset into training set and test set........

# %%
#function for data splitting:
def data_splitter(data):
    F1=data.iloc[:,0:360]
    F2=data.iloc[:,360:720]
    return F1,F2

# %%
Y_label_train,Y_label_test=data_splitter(albedo_map_data)

# %%
# checking that dataset splitting correctly works by plotting graphs

# %%
plt.subplots(figsize=(8,7))
sns.heatmap(Y_label_train,xticklabels=False,yticklabels=False,cmap='gray')

# %%
plt.subplots(figsize=(8,7))
sns.heatmap(Y_label_test,xticklabels=False,yticklabels=False,cmap='gray')

# %%
# now splitting feature training and test sets and converting in numpy array....................

# %%
Fe_features_train,Fe_features_test=data_splitter(Fe_map_data)

# %%
K_features_train,K_features_test=data_splitter(K_map_data)

# %%
Th_features_train,Th_features_test=data_splitter(Th_map_data)

# %%
Ti_features_train,Ti_features_test=data_splitter(Ti_map_data)

# %%
#  now, in order to make a feature set, we have to merge all the different chemical datasets into one with proper positon
# so that we can use them to train and predict.

# %%
# way of merging different chemical datasets: first we will convert the all chemical dataset into a column vector after that
# we will merge all column vector column-wise.
# for label data set, we will also convert it into column vector.

# %%
def column_converter(data):
    data=StandardScaler().fit_transform(data)
    column_arr=data.reshape(-1,1,order='F') # here order='F' specifies that it will read column vice
    return column_arr

# %%
Fe_column_train=column_converter(Fe_features_train)

# %%
Fe_column_train.shape
# Out:
# (129600, 1)

# %%
K_column_train=column_converter(K_features_train)

Th_column_train=column_converter(Th_features_train)

Ti_column_train=column_converter(Ti_features_train)

# %%
# now all the data is converted to column vector now we will add them.

# %%
X_train=np.concatenate((Fe_column_train,K_column_train,Th_column_train,Ti_column_train),axis=1)

# %%
X_train.shape
# Out:
# (129600, 4)

# %%
# now we have our feature set ready,now converting label set.

# %%
Y_train=Y_label_train.values.reshape(-1,1,order='F')

# %%
Y_train.shape
# Out:
# (129600, 1)

# %%
app=np.concatenate((Y_train,X_train),axis=1)
kp=pd.DataFrame(app)
p=kp.corr()
p[0]
# Out:
# 0    1.000000
# 1   -0.629954
# 2   -0.445648
# 3   -0.499353
# 4   -0.492379
# Name: 0, dtype: float64

# %% [markdown]
# ##  Model Training.

# %%
Lin_model=LinearRegression().fit(X_train,Y_train)

# %%
DT_model=DecisionTreeRegressor().fit(X_train,Y_train)

# %%
RF_model=RandomForestRegressor().fit(X_train,Y_train)
# Out:
# C:\Users\NIRBHAY MAURYA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
Rd_model=Ridge().fit(X_train,Y_train)

# %%
Y_train
# Out:
# array([[0.331936],
#        [0.33899 ],
#        [0.32493 ],
#        ...,
#        [0.335923],
#        [0.343421],
#        [0.338815]])

# %%
pred=Rd_model.predict(X_train)

# %%
dat=pred.reshape(360,-1,order='F')
plt.subplots(figsize=(8,7))
sns.heatmap(dat,xticklabels=False,yticklabels=False,cmap='gray')

# %%
r2_score(Y_train,pred)

# %%
r=mean_squared_error(Y_train,pred)

# %%
r

# %%
Fe_column_test=column_converter(Fe_features_test)

K_column_test=column_converter(K_features_test)

Th_column_test=column_converter(Th_features_test)

Ti_column_test=column_converter(Ti_features_test)

X_test=np.concatenate((Fe_column_test,K_column_test,Th_column_test,Ti_column_test),axis=1)

# %%
pred_t=RF_model.predict(X_test)

# %%
dat_t=pred_t.reshape(360,-1,order='F')             
plt.subplots(figsize=(8,7))
sns.heatmap(dat_t,xticklabels=False,yticklabels=False,cmap='gray')

# %%
t=r2_score(Y_label_test,dat_t)

# %%
t
# Out:
# -401.9510740535085

# %%
r=mean_squared_error(Y_label_test,dat_t)

# %%
r
# Out:
# 0.6387245371754593

# %% [raw]
# sc_X=StandardScaler()
# X_train=sc_X.fit_transform(X_train)
# regressor = SVR(kernel = 'rbf',max_iter=70000,epsilon=0.05)
# regressor.fit(X_train, Y_train.ravel())

# %% [raw]
# X_test=sc_X.fit_transform(X_test)
# pred=regressor.predict(X_test)
# dat_ta=pred.reshape(360,-1,order='F')
# plt.subplots(figsize=(8,7))
# sns.heatmap(dat_ta,xticklabels=False,yticklabels=False,cmap='gray')

# %%
#t=r2_score(Y_label_test,dat_ta)

# %%
#t

# %% [raw]
# from keras.models import Sequential
# from keras.layers import Dense

# %% [raw]
# # define the model
# model = Sequential()
# model.add(Dense(10, input_dim=4, kernel_initializer='he_uniform', activation='relu'))
# model.add(Dense(1))
# model.compile(loss='mae', optimizer='adam')
# model.fit(X_train,Y_train,verbose=0,epochs=100)

# %% [raw]
# pred=model.predict(X_test)

# %% [raw]
# map_t=pred.reshape(360,-1,order='F')
# plt.subplots(figsize=(8,7))
# sns.heatmap(map_t,xticklabels=False,yticklabels=False,cmap='gray_r')

# %%
features=np.concatenate((Fe_column_train,(K_column_train+Th_column_train)/2,Ti_column_train),axis=1)

# %%
R_model=Ridge().fit(features,Y_train)

# %%
            
pred=R_model.predict(features)

# %%
dat=pred.reshape(360,-1,order='F') 
plt.subplots(figsize=(8,7))
sns.heatmap(dat,xticklabels=False,yticklabels=False,cmap='gray')

# %%
r2_score(Y_label_train,dat)
# Out:
# -337.5194773762508

# %%
features_test=np.concatenate((Fe_column_test,(K_column_test+Th_column_test)/2,Ti_column_test),axis=1)

# %%
pred_test=R_model.predict(features_test)

# %%
dat_test=pred_test.reshape(360,-1,order='F') 
plt.subplots(data:image/png;base64,...(8,7))
sns.heatmap(dat_test,xticklabels=False,yticklabels=False,cmap='gray')

# %%
r2_score(Y_label_test,dat_test)
# Out:
# -266.34128427292916
